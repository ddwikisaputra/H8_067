# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv")

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df['date_game'] = pd.to_datetime(df['date_game'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
df.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# 126311   Warriors      104  1809.9791  1813.6349              A            L
# 126312   Warriors      105  1813.6349  1822.2881              H            L
# 126313  Cavaliers       97  1700.7391  1692.0859              A            W
#
#         forecast notes
# 126311  0.234435   NaN
# 126312  0.481450   NaN
# ...

# %%
df["gameorder"].dtype
print("INDEX 0 : ", df["gameorder"][0])
# Out:
# INDEX 0 :  1

# %%
df.describe()
# Out:
#                 age
# count  37250.000000
# mean      40.697369
# std       10.220043
# min       17.000000
# 25%       33.000000
# 50%       40.000000
# 75%       48.000000
# max       86.000000

# %%
df[['team_id', 'opp_id', 'game_location']].describe()
# Out:
#        team_id  opp_id game_location
# count   126314  126314        126314
# unique     104     104             3
# top        BOS     BOS             H
# freq      5997    5997         63138

# %%
print("INT64")
df.describe(include='int64')
# Out:
# INT64
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts        opp_pts
# count  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982     102.729982
# std         0.244499      14.814845      14.814845
# min         0.000000       0.000000       0.000000
# 25%         0.000000      93.000000      93.000000
# 50%         0.000000     103.000000     103.000000
# ...

# %%
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# DTF      60
# TRH      60
# INJ      60
# PIT      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df[df['fran_id'] == 'Lakers']['team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df[df['team_id'] == 'MNL']['date_game'].min()
# Out:
# '1/1/1949'

# %%
df[df['team_id'] == 'MNL']['date_game'].max()
# Out:
# '4/9/1959'

# %%
df[df['team_id'] == 'MNL']['date_game'].agg(('min', 'max'))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
df[df['team_id'] == 'MNL'][['date_game', 'year_id']].agg(('min', 'max'))
# Out:
#     date_game  year_id
# min  1/1/1949     1949
# max  4/9/1959     1960

# %%
a = df[['pts', 'opp_pts']][:5].copy()

a
# Out:
#    pts  opp_pts
# 0   66       68
# 1   68       66
# 2   63       47
# 3   47       63
# 4   33       50

# %%
a.agg(('sum'))
# Out:
# pts        277
# opp_pts    294
# dtype: int64

# %%
revenues = pd.Series([5555,7000,1980])

revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.to_frame()
# Out:
#       0
# 0  5555
# 1  7000
# 2  1980

# %%
cityRevenues = pd.Series(
    [4200, 8000, 6500],
    index=['Amsterdam', 'Toronto', 'Tokyo'])

cityRevenues

cityRevenues['Toronto']
# Out:
# 8000

# %%
b = {'Amsterdam' : [1,2,3],
    'Toronto' : [4,5,6]}

b = pd.DataFrame(b)
b
# Out:
#    Amsterdam  Toronto
# 0          1        4
# 1          2        5
# 2          3        6

# %%
cityEmployeeCount = pd.Series({
    'Amsterdam': 5,
    'Tokyo': 15
})

cityEmployeeCount
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
cityEmployeeCount.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
"Tokyo" in cityEmployeeCount
# Out:
# True

# %%
"Tokyo" in cityEmployeeCount.keys()
# Out:
# True

# %%
merges = pd.DataFrame({'revenues': cityRevenues,
                      'emp_count': cityEmployeeCount
                      })

merges
# Out:
#            revenues  emp_count
# Amsterdam      4200        5.0
# Tokyo          6500       15.0
# Toronto        8000        NaN

# %%
merges.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
merges.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 1.5e+01],
#        [8.0e+03,     nan]])

# %%
merges.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenues', 'emp_count'], dtype='object')]

# %%
merges.axes[1]
# Out:
# Index(['revenues', 'emp_count'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
df.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
"is_playoffs" in df.keys()
# Out:
# True

# %%
colors = pd.Series(['red', 'green', 'blue'],
                  index=[1,2,3])
colors
# Out:
# 1      red
# 2    green
# 3     blue
# dtype: object

# %%
print(colors.loc[1]) #berdasarkan index
print(colors.iloc[1]) #berdasarkan baris
# Out:
# red
# green

# %%
merges
# Out:
#            revenues  emp_count
# Amsterdam      4200        5.0
# Tokyo          6500       15.0
# Toronto        8000        NaN

# %%
merges.loc['Amsterdam']
# Out:
# revenues     4200.0
# emp_count       5.0
# Name: Amsterdam, dtype: float64

# %%
merges.loc['Amsterdam']['emp_count']
# Out:
# 5.0

# %%
display(merges)
merges.loc['Amsterdam', 'revenues'] = 500 #khusus update data harus pake loc
display(merges)
# Out:
#            revenues  emp_count
# Amsterdam      4200        5.0
# Tokyo          6500       15.0
# Toronto        8000        NaN
#            revenues  emp_count
# Amsterdam       500        5.0
# Tokyo          6500       15.0
# Toronto        8000        NaN

# %%
df[5555:5559]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 5555       2778  195312310FTW   NBA        0     1954  12/31/1953          30
# 5556       2779  195312310NYK   NBA        1     1954  12/31/1953          33
# 5557       2779  195312310NYK   NBA        0     1954  12/31/1953          30
# 5558       2780  195312310SYR   NBA        1     1954  12/31/1953          29
#
#       is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 5555            0     FTW  Pistons  ...  47.115856     PHW  Warriors       56
# 5556            0     BOS  Celtics  ...  45.189346     NYK    Knicks       74
# 5557            0     NYK   Knicks  ...  45.163074     BOS   Celtics       95
# 5558            0     ROC    Kings  ...  48.589958     SYR    Sixers       86
#
#       opp_elo_i  opp_elo_n  game_location  game_result  forecast  \
# 5555  1421.2324  1414.5690              H            W  0.803381
# ...

# %%
df[5555:5559][['fran_id', 'opp_fran', 'pts', 'opp_pts']]
# Out:
#       fran_id  opp_fran  pts  opp_pts
# 5555  Pistons  Warriors   83       56
# 5556  Celtics    Knicks   95       74
# 5557   Knicks   Celtics   74       95
# 5558    Kings    Sixers   81       86

# %%
currentDecade = df[df['year_id'] > 2010]
currentDecade[['game_id', 'year_id']]
# Out:
#              game_id  year_id
# 113656  201010260BOS     2011
# 113657  201010260BOS     2011
# 113658  201010260LAL     2011
# 113659  201010260LAL     2011
# 113660  201010260POR     2011
# ...              ...      ...
# 126309  201506110CLE     2015
# 126310  201506140GSW     2015
# 126311  201506140GSW     2015
# 126312  201506170CLE     2015
# 126313  201506170CLE     2015
#
# [12658 rows x 2 columns]

# %%
print(currentDecade.iloc[0]['game_id'])
print(currentDecade.iloc[1]['game_id'])
print(currentDecade.iloc[2]['game_id'])
# Out:
# 201010260BOS
# 201010260BOS
# 201010260LAL

# %%
currentDecadeReset = currentDecade.reset_index()
currentDecadeReset[['game_id', 'year_id']]
# Out:
#             game_id  year_id
# 0      201010260BOS     2011
# 1      201010260BOS     2011
# 2      201010260LAL     2011
# 3      201010260LAL     2011
# 4      201010260POR     2011
# ...             ...      ...
# 12653  201506110CLE     2015
# 12654  201506140GSW     2015
# 12655  201506140GSW     2015
# 12656  201506170CLE     2015
# 12657  201506170CLE     2015
#
# [12658 rows x 2 columns]

# %%
df['year_id'].unique()
# Out:
# array([1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957,
#        1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
#        1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
#        1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015])

# %%
gamesWithNotes = df[df['notes'].notnull()]
gamesWithNotes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# ...

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
ers = df[df['fran_id'].str.endswith('ers')] #seperti like (bisa menggunakan startwith, contains, dll)
display(ers.head())
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 7           4  194611020PRO   NBA        0     1947  11/2/1946           1
# 9           5  194611020STB   NBA        0     1947  11/2/1946           1
# 16          9  194611050DTF   NBA        1     1947  11/5/1946           2
# 20         11  194611070PRO   NBA        0     1947  11/7/1946           2
# 22         12  194611070STB   NBA        0     1947  11/7/1946           3
#
#     is_playoffs team_id       fran_id  ...  win_equiv  opp_id  opp_fran  \
# 7             0     PRO  Steamrollers  ...  41.540619     BOS   Celtics
# 9             0     STB       Bombers  ...  41.492020     PIT   Ironmen
# 16            0     STB       Bombers  ...  42.347137     DTF   Falcons
# 20            0     PRO  Steamrollers  ...  42.206284     CHS     Stags
# 22            0     STB       Bombers  ...  41.272594     NYK    Knicks
#
#     opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.groupby(['fran_id', 'team_id']).agg({'pts': 'sum',
                          'opp_pts': 'sum'}) #groupby data
# Out:
#                       pts  opp_pts
# fran_id   team_id
# Baltimore BLB       37219    38924
# Bombers   STB       17793    18059
# Bucks     MIL      418326   414777
# Bulls     CHI      437269   433780
# Capitols  WSC       22387    21815
# ...                   ...      ...
# Wizards   CAP        9019     8889
#           CHP        8874     9553
#           CHZ        8795     9122
#           WAS      142413   145900
#           WSB      207596   209614
#
# [104 rows x 2 columns]

# %%
nba = df.copy()

nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
nba['difference'] = nba['pts'] - nba['opp_pts'] #add new kolom
nba[['pts', 'opp_pts', 'difference']]
# Out:
#         pts  opp_pts  difference
# 0        66       68          -2
# 1        68       66           2
# 2        63       47          16
# 3        47       63         -16
# 4        33       50         -17
# ...     ...      ...         ...
# 126309   82      103         -21
# 126310  104       91          13
# 126311   91      104         -13
# 126312   97      105          -8
# 126313  105       97           8
#
# [126314 rows x 3 columns]

# %%
nba.rename(columns={'difference' : 'diff'}, inplace=True) #rename kolom

nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
nba.drop(columns=['diff'], inplace=True) #hapus kolom
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
nba['game_location'].nunique()
# Out:
# 3

# %%
nba['game_location'] = pd.Categorical(nba['game_location']) #membuat data type menjadi category

nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba['notes'].fillna('-', inplace=True) #replace value per kolom

nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
nba[(nba['pts'] > nba['opp_pts']) & (nba['game_result'] != 'W')].empty #cek data kosong
# Out:
# True

# %%
countries = pd.DataFrame({
    "population": [17,127,37],
    "continent": ["Europe", "Asia", "America"],
    "country": ["Holland", "Japan", "Canada"]
})

countries
# Out:
#    population continent  country
# 0          17    Europe  Holland
# 1         127      Asia    Japan
# 2          37   America   Canada

# %%
merges['country'] = ['Holland', 'Japan', 'Cananda']
merges
# Out:
#            revenues  emp_count  country
# Amsterdam       500        5.0  Holland
# Tokyo          6500       15.0    Japan
# Toronto        8000        NaN  Cananda

# %%
pd.merge(merges, countries, on='country')
# Out:
#    revenues  emp_count  country  population continent
# 0       500        5.0  Holland          17    Europe
# 1      6500       15.0    Japan         127      Asia

# %%
countries = pd.DataFrame({
    "population": [17,127,37],
    "continent": ["Europe", "Asia", "America"],
    "countries": ["Holland", "Japan", "Canada"]
})

countries
# Out:
#    population continent countries
# 0          17    Europe   Holland
# 1         127      Asia     Japan
# 2          37   America    Canada

# %%
pd.merge(merges, countries, left_on='country', right_on='countries') #left dan right jika berbeda nama kolomb
# Out:
#    revenues  emp_count  country  population continent countries
# 0       500        5.0  Holland          17    Europe   Holland
# 1      6500       15.0    Japan         127      Asia     Japan

# %%
# %matplotlib inline #untuk visualisasi data menjadi diagram

# %%
nba['fran_id'].value_counts().head(10).plot(kind="bar") #ambil semua frand_id 10 data pertama
# Out:
# <AxesSubplot:>
